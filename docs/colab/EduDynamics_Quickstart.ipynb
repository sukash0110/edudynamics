# %% [markdown]
# # EduDynamics Quickstart on Colab
#
# This notebook clones the public `EduDynamics` repository, installs the minimal dependencies, and runs the local validation plus the heuristic baseline.

# %%
# !python --version

# %%
# !git clone https://github.com/sukash0110/study_planner_env.git
# %cd study_planner_env

# %%
# !pip install -q -r requirements.txt
# !pip install -q openenv-core

# %% [markdown]
# ## Validate the submission structure

# %%
# !python validate_submission.py

# %% [markdown]
# ## Run the reproducible heuristic baseline

# %%
# !python inference.py --agent heuristic

# %% [markdown]
# ## Optional: run OpenEnv validation
#
# Uncomment if you want the extra OpenEnv packaging check in Colab.

# %%
# !openenv validate
